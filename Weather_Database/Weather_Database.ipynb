# %%
# !pip3 install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\ammon\anaconda3\envs\pythondata\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\ammon\anaconda3\envs\pythondata\lib\site-packages (from citipy) (0.16)

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import json


# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 749

# %%
# Import the requests library.
import requests
# Import the API key.
from config import api_key
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" +api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44067ae0ac6a8916bcf192194ab434cb

# %%
# Create endpoint URL with each city.
city_url = url + "&q=" + city.replace(" ","+")
    
city_weather = requests.get(city_url).json()
city_weather
# Out:
# {'coord': {'lon': 53.3971, 'lat': 35.5729},
#  'weather': [{'id': 801,
#    'main': 'Clouds',
#    'description': 'few clouds',
#    'icon': '02d'}],
#  'base': 'stations',
#  'main': {'temp': 53.44,
#   'feels_like': 50.68,
#   'temp_min': 53.44,
#   'temp_max': 53.44,
#   'pressure': 1010,
#   'humidity': 47},
#  'visibility': 6000,
#  'wind': {'speed': 2.3, 'deg': 190},
#  'clouds': {'all': 20},
#  'dt': 1643981423,
#  'sys': {'type': 1,
#   'id': 7476,
#   'country': 'IR',
#   'sunrise': 1643945051,
#   'sunset': 1643982984},
#  'timezone': 12600,
#  'id': 116402,
#  'name': 'Semnan',
#  'cod': 200}

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description":city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | halalo
# City not found. Skipping...
# Processing Record 3 of Set 1 | fare
# Processing Record 4 of Set 1 | te anau
# Processing Record 5 of Set 1 | puerto ayora
# Processing Record 6 of Set 1 | aswan
# Processing Record 7 of Set 1 | cape town
# Processing Record 8 of Set 1 | jamestown
# Processing Record 9 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | shache
# Processing Record 12 of Set 1 | tura
# Processing Record 13 of Set 1 | lethem
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | samarai
# Processing Record 16 of Set 1 | half moon bay
# Processing Record 17 of Set 1 | hirado
# Processing Record 18 of Set 1 | yambio
# Processing Record 19 of Set 1 | ushuaia
# Processing Record 20 of Set 1 | witrivier
# City not found. Skipping...
# Processing Record 21 of Set 1 | bowen
# Processing Record 22 of Set 1 | busselton
# Processing Record 23 of Set 1 | carnarvon
# Processing Record 24 of Set 1 | koster
# Processing Record 25 of Set 1 | terrace bay
# Processing Record 26 of Set 1 | deputatskiy
# Processing Record 27 of Set 1 | aasiaat
# Processing Record 28 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 29 of Set 1 | saskylakh
# Processing Record 30 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 31 of Set 1 | new norfolk
# Processing Record 32 of Set 1 | pisco
# Processing Record 33 of Set 1 | georgetown
# Processing Record 34 of Set 1 | itarema
# Processing Record 35 of Set 1 | buraydah
# Processing Record 36 of Set 1 | itoman
# Processing Record 37 of Set 1 | abashiri
# Processing Record 38 of Set 1 | kapaa
# Processing Record 39 of Set 1 | hilo
# Processing Record 40 of Set 1 | marawi
# Processing Record 41 of Set 1 | nanortalik
# Processing Record 42 of Set 1 | mecca
# Processing Record 43 of Set 1 | tual
# Processing Record 44 of Set 1 | mandapam
# Processing Record 45 of Set 1 | dikson
# Processing Record 46 of Set 1 | yellowknife
# Processing Record 47 of Set 1 | oksfjord
# Processing Record 48 of Set 1 | kahului
# Processing Record 49 of Set 1 | butaritari
# Processing Record 50 of Set 1 | longyearbyen
# Processing Record 1 of Set 2 | dauphin
# Processing Record 2 of Set 2 | falealupo
# City not found. Skipping...
# Processing Record 3 of Set 2 | ledyard
# Processing Record 4 of Set 2 | ambulu
# Processing Record 5 of Set 2 | bethel
# Processing Record 6 of Set 2 | bud
# Processing Record 7 of Set 2 | cabo san lucas
# Processing Record 8 of Set 2 | antalaha
# Processing Record 9 of Set 2 | saint-leu
# Processing Record 10 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 2 | tuktoyaktuk
# Processing Record 12 of Set 2 | dudinka
# Processing Record 13 of Set 2 | paamiut
# Processing Record 14 of Set 2 | east london
# Processing Record 15 of Set 2 | batemans bay
# Processing Record 16 of Set 2 | tarakan
# Processing Record 17 of Set 2 | blairmore
# Processing Record 18 of Set 2 | bengkulu
# Processing Record 19 of Set 2 | nguiu
# City not found. Skipping...
# Processing Record 20 of Set 2 | lagunas
# Processing Record 21 of Set 2 | nikolskoye
# Processing Record 22 of Set 2 | san quintin
# Processing Record 23 of Set 2 | mana
# Processing Record 24 of Set 2 | barrow
# Processing Record 25 of Set 2 | sola
# Processing Record 26 of Set 2 | bluff
# Processing Record 27 of Set 2 | amapa
# Processing Record 28 of Set 2 | lloydminster
# Processing Record 29 of Set 2 | upernavik
# Processing Record 30 of Set 2 | kaitangata
# Processing Record 31 of Set 2 | crotone
# Processing Record 32 of Set 2 | ostrovnoy
# Processing Record 33 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 34 of Set 2 | araguatins
# City not found. Skipping...
# Processing Record 35 of Set 2 | tasiilaq
# Processing Record 36 of Set 2 | ust-nera
# Processing Record 37 of Set 2 | bredasdorp
# Processing Record 38 of Set 2 | vaini
# Processing Record 39 of Set 2 | scottsbluff
# Processing Record 40 of Set 2 | ozgon
# City not found. Skipping...
# Processing Record 41 of Set 2 | sur
# Processing Record 42 of Set 2 | karamea
# City not found. Skipping...
# Processing Record 43 of Set 2 | komsomolskiy
# Processing Record 44 of Set 2 | pasni
# Processing Record 45 of Set 2 | murupara
# Processing Record 46 of Set 2 | bambous virieux
# Processing Record 47 of Set 2 | nikki
# Processing Record 48 of Set 2 | sitka
# Processing Record 49 of Set 2 | turukhansk
# Processing Record 50 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 1 of Set 3 | klaksvik
# Processing Record 2 of Set 3 | acapulco
# Processing Record 3 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 4 of Set 3 | axim
# Processing Record 5 of Set 3 | talaya
# Processing Record 6 of Set 3 | morros
# Processing Record 7 of Set 3 | sao joao da barra
# Processing Record 8 of Set 3 | kodiak
# Processing Record 9 of Set 3 | kosino
# Processing Record 10 of Set 3 | champerico
# Processing Record 11 of Set 3 | urucara
# Processing Record 12 of Set 3 | atuona
# Processing Record 13 of Set 3 | iracoubo
# Processing Record 14 of Set 3 | trincomalee
# Processing Record 15 of Set 3 | tiksi
# Processing Record 16 of Set 3 | karratha
# Processing Record 17 of Set 3 | geraldton
# Processing Record 18 of Set 3 | decatur
# Processing Record 19 of Set 3 | olinda
# Processing Record 20 of Set 3 | tiznit
# Processing Record 21 of Set 3 | usinsk
# Processing Record 22 of Set 3 | kalakamati
# Processing Record 23 of Set 3 | thompson
# Processing Record 24 of Set 3 | victoria
# Processing Record 25 of Set 3 | pevek
# Processing Record 26 of Set 3 | qaanaaq
# Processing Record 27 of Set 3 | lufilufi
# Processing Record 28 of Set 3 | mandalgovi
# Processing Record 29 of Set 3 | zhuanghe
# Processing Record 30 of Set 3 | esperance
# Processing Record 31 of Set 3 | castro
# Processing Record 32 of Set 3 | okha
# Processing Record 33 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 34 of Set 3 | hermanus
# Processing Record 35 of Set 3 | severo-kurilsk
# Processing Record 36 of Set 3 | lasa
# Processing Record 37 of Set 3 | pangnirtung
# Processing Record 38 of Set 3 | carballo
# Processing Record 39 of Set 3 | cherskiy
# Processing Record 40 of Set 3 | sibu
# Processing Record 41 of Set 3 | hobart
# Processing Record 42 of Set 3 | bairiki
# Processing Record 43 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 44 of Set 3 | kruisfontein
# Processing Record 45 of Set 3 | sioux lookout
# Processing Record 46 of Set 3 | uige
# Processing Record 47 of Set 3 | hamilton
# Processing Record 48 of Set 3 | flinders
# Processing Record 49 of Set 3 | birin
# Processing Record 50 of Set 3 | albany
# Processing Record 1 of Set 4 | nyurba
# Processing Record 2 of Set 4 | leningradskiy
# Processing Record 3 of Set 4 | tabialan
# City not found. Skipping...
# Processing Record 4 of Set 4 | kaduqli
# Processing Record 5 of Set 4 | constitucion
# Processing Record 6 of Set 4 | mullaitivu
# City not found. Skipping...
# Processing Record 7 of Set 4 | galgani
# City not found. Skipping...
# Processing Record 8 of Set 4 | san cristobal
# Processing Record 9 of Set 4 | broome
# Processing Record 10 of Set 4 | rincon
# Processing Record 11 of Set 4 | luderitz
# Processing Record 12 of Set 4 | langarud
# Processing Record 13 of Set 4 | taltal
# Processing Record 14 of Set 4 | janakpur road
# City not found. Skipping...
# Processing Record 15 of Set 4 | ponta do sol
# Processing Record 16 of Set 4 | moron
# Processing Record 17 of Set 4 | isla vista
# Processing Record 18 of Set 4 | beloha
# Processing Record 19 of Set 4 | saint anthony
# Processing Record 20 of Set 4 | gogapur
# Processing Record 21 of Set 4 | port alfred
# Processing Record 22 of Set 4 | hasaki
# Processing Record 23 of Set 4 | taganak
# Processing Record 24 of Set 4 | shakhtinsk
# Processing Record 25 of Set 4 | shenjiamen
# Processing Record 26 of Set 4 | puerto escondido
# Processing Record 27 of Set 4 | qabis
# City not found. Skipping...
# Processing Record 28 of Set 4 | bell ville
# Processing Record 29 of Set 4 | mar del plata
# Processing Record 30 of Set 4 | brae
# Processing Record 31 of Set 4 | takaungu
# Processing Record 32 of Set 4 | lima
# Processing Record 33 of Set 4 | lebu
# Processing Record 34 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 4 | airai
# Processing Record 36 of Set 4 | lavrentiya
# Processing Record 37 of Set 4 | poum
# Processing Record 38 of Set 4 | mangrol
# Processing Record 39 of Set 4 | alberton
# Processing Record 40 of Set 4 | mount isa
# Processing Record 41 of Set 4 | shelburne
# Processing Record 42 of Set 4 | avarua
# Processing Record 43 of Set 4 | tuatapere
# Processing Record 44 of Set 4 | chokurdakh
# Processing Record 45 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 46 of Set 4 | bemidji
# Processing Record 47 of Set 4 | iqaluit
# Processing Record 48 of Set 4 | sinnamary
# Processing Record 49 of Set 4 | prainha
# Processing Record 50 of Set 4 | lyngseidet
# Processing Record 1 of Set 5 | markala
# Processing Record 2 of Set 5 | vuktyl
# Processing Record 3 of Set 5 | blagoyevo
# Processing Record 4 of Set 5 | arman
# Processing Record 5 of Set 5 | taupo
# Processing Record 6 of Set 5 | buala
# Processing Record 7 of Set 5 | micheweni
# Processing Record 8 of Set 5 | kavieng
# Processing Record 9 of Set 5 | saint george
# Processing Record 10 of Set 5 | svetlyy
# Processing Record 11 of Set 5 | santiago
# Processing Record 12 of Set 5 | bayan
# Processing Record 13 of Set 5 | guicheng
# City not found. Skipping...
# Processing Record 14 of Set 5 | mahebourg
# Processing Record 15 of Set 5 | dalby
# Processing Record 16 of Set 5 | diffa
# Processing Record 17 of Set 5 | tingi
# Processing Record 18 of Set 5 | anadyr
# Processing Record 19 of Set 5 | arraial do cabo
# Processing Record 20 of Set 5 | trinidad
# Processing Record 21 of Set 5 | batsfjord
# Processing Record 22 of Set 5 | brovary
# Processing Record 23 of Set 5 | boyolangu
# Processing Record 24 of Set 5 | port elizabeth
# Processing Record 25 of Set 5 | fortuna
# Processing Record 26 of Set 5 | fairbanks
# Processing Record 27 of Set 5 | gaozhou
# Processing Record 28 of Set 5 | talnakh
# Processing Record 29 of Set 5 | caravelas
# Processing Record 30 of Set 5 | vao
# Processing Record 31 of Set 5 | black river
# Processing Record 32 of Set 5 | iskateley
# Processing Record 33 of Set 5 | ouesso
# Processing Record 34 of Set 5 | cidreira
# Processing Record 35 of Set 5 | padang
# Processing Record 36 of Set 5 | maroantsetra
# Processing Record 37 of Set 5 | inongo
# Processing Record 38 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 39 of Set 5 | ukiah
# Processing Record 40 of Set 5 | sibolga
# Processing Record 41 of Set 5 | tessalit
# Processing Record 42 of Set 5 | saint-philippe
# Processing Record 43 of Set 5 | norman wells
# Processing Record 44 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 45 of Set 5 | russell
# Processing Record 46 of Set 5 | inyonga
# Processing Record 47 of Set 5 | katsuura
# Processing Record 48 of Set 5 | aljezur
# Processing Record 49 of Set 5 | xinxiang
# Processing Record 50 of Set 5 | nantucket
# Processing Record 1 of Set 6 | san patricio
# Processing Record 2 of Set 6 | bandarbeyla
# Processing Record 3 of Set 6 | el tigre
# Processing Record 4 of Set 6 | kyren
# Processing Record 5 of Set 6 | matamoros
# Processing Record 6 of Set 6 | babanusah
# City not found. Skipping...
# Processing Record 7 of Set 6 | labuhan
# Processing Record 8 of Set 6 | takoradi
# Processing Record 9 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 10 of Set 6 | thunder bay
# Processing Record 11 of Set 6 | ugoofaaru
# Processing Record 12 of Set 6 | adre
# Processing Record 13 of Set 6 | dunedin
# Processing Record 14 of Set 6 | boralday
# Processing Record 15 of Set 6 | bahir dar
# Processing Record 16 of Set 6 | svetlaya
# Processing Record 17 of Set 6 | clyde river
# Processing Record 18 of Set 6 | ribeira grande
# Processing Record 19 of Set 6 | marystown
# Processing Record 20 of Set 6 | yumbe
# Processing Record 21 of Set 6 | codrington
# Processing Record 22 of Set 6 | praia da vitoria
# Processing Record 23 of Set 6 | ca mau
# Processing Record 24 of Set 6 | provideniya
# Processing Record 25 of Set 6 | bon air
# Processing Record 26 of Set 6 | touros
# Processing Record 27 of Set 6 | ahipara
# Processing Record 28 of Set 6 | surt
# Processing Record 29 of Set 6 | namibe
# Processing Record 30 of Set 6 | aksu
# Processing Record 31 of Set 6 | carnot
# Processing Record 32 of Set 6 | gornyak
# Processing Record 33 of Set 6 | bilibino
# Processing Record 34 of Set 6 | ust-omchug
# Processing Record 35 of Set 6 | aklavik
# Processing Record 36 of Set 6 | hithadhoo
# Processing Record 37 of Set 6 | callaway
# Processing Record 38 of Set 6 | shu
# Processing Record 39 of Set 6 | broken hill
# Processing Record 40 of Set 6 | keflavik
# Processing Record 41 of Set 6 | skjervoy
# Processing Record 42 of Set 6 | laguna de perlas
# Processing Record 43 of Set 6 | eunice
# Processing Record 44 of Set 6 | nakatsu
# Processing Record 45 of Set 6 | macamic
# Processing Record 46 of Set 6 | havoysund
# Processing Record 47 of Set 6 | roald
# Processing Record 48 of Set 6 | pilar
# Processing Record 49 of Set 6 | tautira
# Processing Record 50 of Set 6 | souris
# Processing Record 1 of Set 7 | narsaq
# Processing Record 2 of Set 7 | vila franca do campo
# Processing Record 3 of Set 7 | vila velha
# Processing Record 4 of Set 7 | krasnyy chikoy
# Processing Record 5 of Set 7 | kamyshin
# Processing Record 6 of Set 7 | pamekasan
# Processing Record 7 of Set 7 | khatanga
# Processing Record 8 of Set 7 | sembe
# Processing Record 9 of Set 7 | port-gentil
# Processing Record 10 of Set 7 | nguruka
# Processing Record 11 of Set 7 | cerrik
# Processing Record 12 of Set 7 | tommot
# Processing Record 13 of Set 7 | tilichiki
# Processing Record 14 of Set 7 | maralal
# Processing Record 15 of Set 7 | phan rang
# City not found. Skipping...
# Processing Record 16 of Set 7 | zuhres
# Processing Record 17 of Set 7 | porto santo
# Processing Record 18 of Set 7 | aras
# Processing Record 19 of Set 7 | songjianghe
# Processing Record 20 of Set 7 | saint-joseph
# Processing Record 21 of Set 7 | meulaboh
# Processing Record 22 of Set 7 | baruun-urt
# Processing Record 23 of Set 7 | traiguen
# Processing Record 24 of Set 7 | alekseyevka
# Processing Record 25 of Set 7 | saldanha
# Processing Record 26 of Set 7 | vardo
# Processing Record 27 of Set 7 | salalah
# Processing Record 28 of Set 7 | elko
# Processing Record 29 of Set 7 | tucurui
# Processing Record 30 of Set 7 | cairns
# Processing Record 31 of Set 7 | faya
# Processing Record 32 of Set 7 | port lincoln
# Processing Record 33 of Set 7 | dzhebariki-khaya
# Processing Record 34 of Set 7 | abu dhabi
# Processing Record 35 of Set 7 | khandyga
# Processing Record 36 of Set 7 | mackay
# Processing Record 37 of Set 7 | watsa
# Processing Record 38 of Set 7 | mount pleasant
# Processing Record 39 of Set 7 | mogadishu
# Processing Record 40 of Set 7 | xichang
# Processing Record 41 of Set 7 | namatanai
# Processing Record 42 of Set 7 | alyangula
# Processing Record 43 of Set 7 | traverse city
# Processing Record 44 of Set 7 | nueva san salvador
# City not found. Skipping...
# Processing Record 45 of Set 7 | la reforma
# Processing Record 46 of Set 7 | malakal
# Processing Record 47 of Set 7 | wellington
# Processing Record 48 of Set 7 | kargasok
# Processing Record 49 of Set 7 | zyryanovsk
# Processing Record 50 of Set 7 | camacha
# Processing Record 1 of Set 8 | porto novo
# Processing Record 2 of Set 8 | outjo
# Processing Record 3 of Set 8 | elliot lake
# Processing Record 4 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 5 of Set 8 | jalu
# Processing Record 6 of Set 8 | gwadar
# Processing Record 7 of Set 8 | bay roberts
# Processing Record 8 of Set 8 | college
# Processing Record 9 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 10 of Set 8 | walvis bay
# Processing Record 11 of Set 8 | rabo de peixe
# Processing Record 12 of Set 8 | coquimbo
# Processing Record 13 of Set 8 | yulara
# Processing Record 14 of Set 8 | benguela
# Processing Record 15 of Set 8 | hofn
# Processing Record 16 of Set 8 | dire
# Processing Record 17 of Set 8 | la primavera
# Processing Record 18 of Set 8 | preobrazhenskaya
# City not found. Skipping...
# Processing Record 19 of Set 8 | san carlos
# Processing Record 20 of Set 8 | byron bay
# Processing Record 21 of Set 8 | west bay
# Processing Record 22 of Set 8 | de aar
# Processing Record 23 of Set 8 | pinheiro
# Processing Record 24 of Set 8 | bumba
# Processing Record 25 of Set 8 | kamenka
# Processing Record 26 of Set 8 | ilulissat
# Processing Record 27 of Set 8 | zhigansk
# Processing Record 28 of Set 8 | port macquarie
# Processing Record 29 of Set 8 | antofagasta
# Processing Record 30 of Set 8 | mnogovershinnyy
# Processing Record 31 of Set 8 | vallenar
# Processing Record 32 of Set 8 | escarcega
# Processing Record 33 of Set 8 | pemba
# Processing Record 34 of Set 8 | nouadhibou
# Processing Record 35 of Set 8 | harrison
# Processing Record 36 of Set 8 | andarab
# City not found. Skipping...
# Processing Record 37 of Set 8 | biak
# Processing Record 38 of Set 8 | kipushi
# Processing Record 39 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 40 of Set 8 | qinggang
# Processing Record 41 of Set 8 | road town
# Processing Record 42 of Set 8 | mayo
# Processing Record 43 of Set 8 | maine-soroa
# Processing Record 44 of Set 8 | nanakuli
# Processing Record 45 of Set 8 | barra
# Processing Record 46 of Set 8 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 47 of Set 8 | burley
# Processing Record 48 of Set 8 | fabianhaza
# City not found. Skipping...
# Processing Record 49 of Set 8 | waterloo
# Processing Record 50 of Set 8 | kuli
# Processing Record 1 of Set 9 | lujan
# Processing Record 2 of Set 9 | los andes
# Processing Record 3 of Set 9 | karak
# Processing Record 4 of Set 9 | cuajinicuilapa
# Processing Record 5 of Set 9 | ancud
# Processing Record 6 of Set 9 | lazaro cardenas
# Processing Record 7 of Set 9 | ribas do rio pardo
# Processing Record 8 of Set 9 | passo de camaragibe
# Processing Record 9 of Set 9 | soyo
# Processing Record 10 of Set 9 | gubkinskiy
# Processing Record 11 of Set 9 | ullapool
# Processing Record 12 of Set 9 | hargeysa
# Processing Record 13 of Set 9 | maceio
# Processing Record 14 of Set 9 | bama
# Processing Record 15 of Set 9 | grand gaube
# Processing Record 16 of Set 9 | lata
# Processing Record 17 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 18 of Set 9 | coihaique
# Processing Record 19 of Set 9 | koumac
# Processing Record 20 of Set 9 | nelson bay
# Processing Record 21 of Set 9 | nha trang
# Processing Record 22 of Set 9 | santarem
# Processing Record 23 of Set 9 | khonsa
# Processing Record 24 of Set 9 | plettenberg bay
# Processing Record 25 of Set 9 | bonthe
# Processing Record 26 of Set 9 | rawlins
# Processing Record 27 of Set 9 | lagos
# Processing Record 28 of Set 9 | port moresby
# Processing Record 29 of Set 9 | lumphat
# Processing Record 30 of Set 9 | todos santos
# Processing Record 31 of Set 9 | tateyama
# Processing Record 32 of Set 9 | romny
# Processing Record 33 of Set 9 | beringovskiy
# Processing Record 34 of Set 9 | hun
# Processing Record 35 of Set 9 | panjwin
# City not found. Skipping...
# Processing Record 36 of Set 9 | nara
# Processing Record 37 of Set 9 | whangamata
# Processing Record 38 of Set 9 | okhotsk
# Processing Record 39 of Set 9 | placido de castro
# Processing Record 40 of Set 9 | longlac
# City not found. Skipping...
# Processing Record 41 of Set 9 | chongqing
# Processing Record 42 of Set 9 | mufumbwe
# Processing Record 43 of Set 9 | saint-georges
# Processing Record 44 of Set 9 | nakhon nayok
# Processing Record 45 of Set 9 | narasannapeta
# Processing Record 46 of Set 9 | abong mbang
# Processing Record 47 of Set 9 | san jose
# Processing Record 48 of Set 9 | pitimbu
# Processing Record 49 of Set 9 | progreso
# Processing Record 50 of Set 9 | tottori
# Processing Record 1 of Set 10 | chuy
# Processing Record 2 of Set 10 | fukue
# Processing Record 3 of Set 10 | mogocha
# Processing Record 4 of Set 10 | abbeville
# Processing Record 5 of Set 10 | sao filipe
# Processing Record 6 of Set 10 | puerto morazan
# Processing Record 7 of Set 10 | mayor pablo lagerenza
# Processing Record 8 of Set 10 | rocha
# Processing Record 9 of Set 10 | mounana
# Processing Record 10 of Set 10 | belmonte
# Processing Record 11 of Set 10 | nassjo
# Processing Record 12 of Set 10 | isangel
# Processing Record 13 of Set 10 | ngunguru
# Processing Record 14 of Set 10 | hvammstangi
# City not found. Skipping...
# Processing Record 15 of Set 10 | atambua
# Processing Record 16 of Set 10 | moranbah
# Processing Record 17 of Set 10 | nome
# Processing Record 18 of Set 10 | kenora
# Processing Record 19 of Set 10 | guantanamo
# Processing Record 20 of Set 10 | adrar
# Processing Record 21 of Set 10 | monte patria
# Processing Record 22 of Set 10 | diego de almagro
# Processing Record 23 of Set 10 | sorland
# Processing Record 24 of Set 10 | tsaratanana
# Processing Record 25 of Set 10 | severodvinsk
# Processing Record 26 of Set 10 | aromashevo
# Processing Record 27 of Set 10 | yantal
# Processing Record 28 of Set 10 | kurilsk
# Processing Record 29 of Set 10 | tazovskiy
# Processing Record 30 of Set 10 | elat
# Processing Record 31 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 32 of Set 10 | lalmohan
# Processing Record 33 of Set 10 | marzuq
# Processing Record 34 of Set 10 | camana
# Processing Record 35 of Set 10 | taoudenni
# Processing Record 36 of Set 10 | quatre cocos
# Processing Record 37 of Set 10 | whyalla
# Processing Record 38 of Set 10 | mapastepec
# Processing Record 39 of Set 10 | willmar
# Processing Record 40 of Set 10 | husavik
# Processing Record 41 of Set 10 | obra
# Processing Record 42 of Set 10 | dingle
# Processing Record 43 of Set 10 | buin
# Processing Record 44 of Set 10 | urgut
# Processing Record 45 of Set 10 | wuwei
# Processing Record 46 of Set 10 | thornbury
# Processing Record 47 of Set 10 | lompoc
# Processing Record 48 of Set 10 | pindiga
# Processing Record 49 of Set 10 | kedarnath
# City not found. Skipping...
# Processing Record 50 of Set 10 | yeletskiy
# City not found. Skipping...
# Processing Record 1 of Set 11 | port blair
# Processing Record 2 of Set 11 | sarkand
# Processing Record 3 of Set 11 | rolim de moura
# City not found. Skipping...
# Processing Record 4 of Set 11 | sobolevo
# Processing Record 5 of Set 11 | coldstream
# Processing Record 6 of Set 11 | lagoa
# Processing Record 7 of Set 11 | bloemfontein
# Processing Record 8 of Set 11 | sirohi
# Processing Record 9 of Set 11 | neyshabur
# Processing Record 10 of Set 11 | kampot
# Processing Record 11 of Set 11 | darnah
# Processing Record 12 of Set 11 | nizwa
# Processing Record 13 of Set 11 | turayf
# Processing Record 14 of Set 11 | jand
# Processing Record 15 of Set 11 | cockburn harbour
# City not found. Skipping...
# Processing Record 16 of Set 11 | anisoc
# Processing Record 17 of Set 11 | ekangala
# Processing Record 18 of Set 11 | braganca
# Processing Record 19 of Set 11 | banda aceh
# Processing Record 20 of Set 11 | atherton
# Processing Record 21 of Set 11 | garmsar
# Processing Record 22 of Set 11 | wangqing
# Processing Record 23 of Set 11 | bolshiye uki
# City not found. Skipping...
# Processing Record 24 of Set 11 | udachnyy
# Processing Record 25 of Set 11 | ambilobe
# Processing Record 26 of Set 11 | ponta delgada
# Processing Record 27 of Set 11 | muli
# Processing Record 28 of Set 11 | disna
# Processing Record 29 of Set 11 | skibbereen
# Processing Record 30 of Set 11 | tolaga bay
# Processing Record 31 of Set 11 | kollam
# Processing Record 32 of Set 11 | muborak
# Processing Record 33 of Set 11 | uttaradit
# Processing Record 34 of Set 11 | hecun
# Processing Record 35 of Set 11 | pagman
# City not found. Skipping...
# Processing Record 36 of Set 11 | leh
# Processing Record 37 of Set 11 | xam nua
# Processing Record 38 of Set 11 | west helena
# Processing Record 39 of Set 11 | coronado
# Processing Record 40 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 41 of Set 11 | jiuquan
# Processing Record 42 of Set 11 | cap malheureux
# Processing Record 43 of Set 11 | kavaratti
# Processing Record 44 of Set 11 | abu samrah
# Processing Record 45 of Set 11 | svetlogorsk
# Processing Record 46 of Set 11 | springfield
# Processing Record 47 of Set 11 | galesong
# Processing Record 48 of Set 11 | bagula
# Processing Record 49 of Set 11 | huanren
# Processing Record 50 of Set 11 | pringsewu
# Processing Record 1 of Set 12 | cayenne
# Processing Record 2 of Set 12 | shakawe
# Processing Record 3 of Set 12 | yar-sale
# Processing Record 4 of Set 12 | jan kempdorp
# Processing Record 5 of Set 12 | tasbuget
# City not found. Skipping...
# Processing Record 6 of Set 12 | fevralsk
# City not found. Skipping...
# Processing Record 7 of Set 12 | taburao
# City not found. Skipping...
# Processing Record 8 of Set 12 | kigoma
# Processing Record 9 of Set 12 | ha giang
# Processing Record 10 of Set 12 | wawa
# Processing Record 11 of Set 12 | dolbeau
# City not found. Skipping...
# Processing Record 12 of Set 12 | oussouye
# Processing Record 13 of Set 12 | zharkent
# Processing Record 14 of Set 12 | juazeiro
# Processing Record 15 of Set 12 | zheleznodorozhnyy
# Processing Record 16 of Set 12 | atbasar
# Processing Record 17 of Set 12 | yazman
# Processing Record 18 of Set 12 | hami
# Processing Record 19 of Set 12 | dargaville
# Processing Record 20 of Set 12 | portland
# Processing Record 21 of Set 12 | tucuman
# Processing Record 22 of Set 12 | moorhead
# Processing Record 23 of Set 12 | djibo
# Processing Record 24 of Set 12 | gat
# Processing Record 25 of Set 12 | bonavista
# Processing Record 26 of Set 12 | oistins
# Processing Record 27 of Set 12 | boda
# Processing Record 28 of Set 12 | areka
# Processing Record 29 of Set 12 | yuzhno-sukhokumsk
# Processing Record 30 of Set 12 | pacific grove
# Processing Record 31 of Set 12 | vigrestad
# Processing Record 32 of Set 12 | bridgetown
# Processing Record 33 of Set 12 | daru
# Processing Record 34 of Set 12 | grindavik
# Processing Record 35 of Set 12 | hambantota
# Processing Record 36 of Set 12 | kidal
# Processing Record 37 of Set 12 | chumikan
# Processing Record 38 of Set 12 | tarauaca
# Processing Record 39 of Set 12 | ixtapa
# Processing Record 40 of Set 12 | cam ranh
# Processing Record 41 of Set 12 | turbiv
# Processing Record 42 of Set 12 | gobabis
# Processing Record 43 of Set 12 | keroka
# Processing Record 44 of Set 12 | aloleng
# Processing Record 45 of Set 12 | dukat
# Processing Record 46 of Set 12 | harper
# Processing Record 47 of Set 12 | tevriz
# Processing Record 48 of Set 12 | svencionys
# Processing Record 49 of Set 12 | waitati
# Processing Record 50 of Set 12 | angono
# Processing Record 1 of Set 13 | lafayette
# Processing Record 2 of Set 13 | north platte
# Processing Record 3 of Set 13 | derzhavinsk
# Processing Record 4 of Set 13 | souillac
# Processing Record 5 of Set 13 | gazanjyk
# Processing Record 6 of Set 13 | kulhudhuffushi
# Processing Record 7 of Set 13 | vikulovo
# Processing Record 8 of Set 13 | pangkalanbuun
# Processing Record 9 of Set 13 | kutum
# Processing Record 10 of Set 13 | athabasca
# Processing Record 11 of Set 13 | iki-burul
# Processing Record 12 of Set 13 | sarishabari
# Processing Record 13 of Set 13 | kuching
# Processing Record 14 of Set 13 | duz
# City not found. Skipping...
# Processing Record 15 of Set 13 | kirakira
# Processing Record 16 of Set 13 | khasan
# Processing Record 17 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 18 of Set 13 | bilma
# Processing Record 19 of Set 13 | buqayq
# City not found. Skipping...
# Processing Record 20 of Set 13 | roma
# Processing Record 21 of Set 13 | rawson
# Processing Record 22 of Set 13 | la palma
# Processing Record 23 of Set 13 | manggar
# Processing Record 24 of Set 13 | koson
# Processing Record 25 of Set 13 | quchan
# Processing Record 26 of Set 13 | ordynskoye
# Processing Record 27 of Set 13 | port hardy
# Processing Record 28 of Set 13 | mount gambier
# Processing Record 29 of Set 13 | atoyac
# Processing Record 30 of Set 13 | karasburg
# Processing Record 31 of Set 13 | faanui
# Processing Record 32 of Set 13 | berlevag
# Processing Record 33 of Set 13 | chapais
# Processing Record 34 of Set 13 | bang saphan
# Processing Record 35 of Set 13 | solovetskiy
# City not found. Skipping...
# Processing Record 36 of Set 13 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 37 of Set 13 | kampene
# Processing Record 38 of Set 13 | tombouctou
# Processing Record 39 of Set 13 | mombetsu
# Processing Record 40 of Set 13 | sao felix do xingu
# Processing Record 41 of Set 13 | torbay
# Processing Record 42 of Set 13 | ippy
# Processing Record 43 of Set 13 | tuburan
# Processing Record 44 of Set 13 | waingapu
# Processing Record 45 of Set 13 | berdigestyakh
# Processing Record 46 of Set 13 | uarini
# Processing Record 47 of Set 13 | villa carlos paz
# Processing Record 48 of Set 13 | cockburn town
# Processing Record 49 of Set 13 | qaqortoq
# Processing Record 50 of Set 13 | aporawan
# City not found. Skipping...
# Processing Record 1 of Set 14 | riyadh
# Processing Record 2 of Set 14 | bandiagara
# Processing Record 3 of Set 14 | takab
# Processing Record 4 of Set 14 | naryan-mar
# Processing Record 5 of Set 14 | zirandaro
# Processing Record 6 of Set 14 | jasper
# Processing Record 7 of Set 14 | nacala
# Processing Record 8 of Set 14 | kerman
# Processing Record 9 of Set 14 | lerum
# Processing Record 10 of Set 14 | noyabrsk
# Processing Record 11 of Set 14 | mehamn
# Processing Record 12 of Set 14 | boa vista
# Processing Record 13 of Set 14 | sakakah
# Processing Record 14 of Set 14 | bathsheba
# Processing Record 15 of Set 14 | knysna
# Processing Record 16 of Set 14 | kijang
# Processing Record 17 of Set 14 | realeza
# Processing Record 18 of Set 14 | kaeo
# Processing Record 19 of Set 14 | huarmey
# Processing Record 20 of Set 14 | iwanai
# Processing Record 21 of Set 14 | masyaf
# Processing Record 22 of Set 14 | carutapera
# Processing Record 23 of Set 14 | eyl
# Processing Record 24 of Set 14 | vaitupu
# City not found. Skipping...
# Processing Record 25 of Set 14 | tartagal
# Processing Record 26 of Set 14 | charagua
# Processing Record 27 of Set 14 | srednekolymsk
# Processing Record 28 of Set 14 | palmer
# Processing Record 29 of Set 14 | sinazongwe
# Processing Record 30 of Set 14 | magna
# Processing Record 31 of Set 14 | laguna
# Processing Record 32 of Set 14 | satitoa
# City not found. Skipping...
# Processing Record 33 of Set 14 | rodos
# Processing Record 34 of Set 14 | calamar
# Processing Record 35 of Set 14 | salisbury
# Processing Record 36 of Set 14 | katobu
# Processing Record 37 of Set 14 | banjar
# Processing Record 38 of Set 14 | jutai
# Processing Record 39 of Set 14 | stornoway
# City not found. Skipping...
# Processing Record 40 of Set 14 | utiroa
# City not found. Skipping...
# Processing Record 41 of Set 14 | lapua
# Processing Record 42 of Set 14 | artyk
# City not found. Skipping...
# Processing Record 43 of Set 14 | hobyo
# Processing Record 44 of Set 14 | manavgat
# Processing Record 45 of Set 14 | aykhal
# Processing Record 46 of Set 14 | wenatchee
# Processing Record 47 of Set 14 | nizhniy tsasuchey
# Processing Record 48 of Set 14 | liling
# Processing Record 49 of Set 14 | bjelovar
# Processing Record 50 of Set 14 | wolbrom
# Processing Record 1 of Set 15 | mendoza
# Processing Record 2 of Set 15 | baykit
# Processing Record 3 of Set 15 | bismarck
# Processing Record 4 of Set 15 | fossano
# Processing Record 5 of Set 15 | yanam
# Processing Record 6 of Set 15 | louisbourg
# City not found. Skipping...
# Processing Record 7 of Set 15 | teknaf
# Processing Record 8 of Set 15 | magistralnyy
# Processing Record 9 of Set 15 | powell
# Processing Record 10 of Set 15 | amazar
# Processing Record 11 of Set 15 | rameswaram
# Processing Record 12 of Set 15 | karpuninskiy
# City not found. Skipping...
# Processing Record 13 of Set 15 | roebourne
# Processing Record 14 of Set 15 | mezen
# Processing Record 15 of Set 15 | richards bay
# Processing Record 16 of Set 15 | aizpute
# Processing Record 17 of Set 15 | weymouth
# Processing Record 18 of Set 15 | salinopolis
# Processing Record 19 of Set 15 | de-kastri
# Processing Record 20 of Set 15 | urumqi
# Processing Record 21 of Set 15 | palauig
# Processing Record 22 of Set 15 | terrasini
# Processing Record 23 of Set 15 | camocim
# Processing Record 24 of Set 15 | launceston
# Processing Record 25 of Set 15 | zhoucheng
# Processing Record 26 of Set 15 | abeche
# Processing Record 27 of Set 15 | opatija
# Processing Record 28 of Set 15 | kyshtovka
# Processing Record 29 of Set 15 | lorengau
# Processing Record 30 of Set 15 | urk
# Processing Record 31 of Set 15 | qabaqcol
# Processing Record 32 of Set 15 | vestmannaeyjar
# Processing Record 33 of Set 15 | peleduy
# Processing Record 34 of Set 15 | murgab
# Processing Record 35 of Set 15 | moose factory
# Processing Record 36 of Set 15 | birao
# Processing Record 37 of Set 15 | vanimo
# Processing Record 38 of Set 15 | ayagoz
# Processing Record 39 of Set 15 | koroni
# Processing Record 40 of Set 15 | grand centre
# City not found. Skipping...
# Processing Record 41 of Set 15 | nizhnevartovsk
# Processing Record 42 of Set 15 | tipitapa
# Processing Record 43 of Set 15 | gamba
# Processing Record 44 of Set 15 | vrangel
# Processing Record 45 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 46 of Set 15 | eureka
# Processing Record 47 of Set 15 | ketchikan
# Processing Record 48 of Set 15 | kanie
# Processing Record 49 of Set 15 | semnan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Mataura -46.1927  168.8643     49.48        99         100
# 1          Fare -16.7000 -151.0167     80.04        76          10
# 2       Te Anau -45.4167  167.7167     43.07        93         100
# 3  Puerto Ayora  -0.7393  -90.3518     75.54        93           7
# 4         Aswan  24.0934   32.9070     64.85        21           0
# 5     Cape Town -33.9258   18.4232     73.81        46           0
# 6     Jamestown  42.0970  -79.2353     19.09        66         100
# 7       Rikitea -23.1203 -134.9692     77.74        73         100
# 8        Shache  38.4167   77.2406     30.06        37           7
# 9          Tura  25.5198   90.2201     54.25        95         100
#
#    Wind Speed Country                 Date Current Description
# 0        2.15      NZ  2022-02-04 13:35:27     overcast clouds
# 1       13.80      PF  2022-02-04 13:35:27          light rain
# 2        3.44      NZ  2022-02-04 13:35:28     overcast clouds
# 3        8.01      EC  2022-02-04 13:35:28           clear sky
# 4       19.17      EG  2022-02-04 13:35:28           clear sky
# 5        5.99      ZA  2022-02-04 13:33:55           clear sky
# 6        1.99      US  2022-02-04 13:35:29                mist
# 7       12.30      PF  2022-02-04 13:35:29     overcast clouds
# 8        7.67      CN  2022-02-04 13:35:29           clear sky
# 9        5.79      IN  2022-02-04 13:33:08     overcast clouds

# %%
new_column_order = ["City", "Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Mataura      NZ -46.1927  168.8643     49.48        99         100
# 1          Fare      PF -16.7000 -151.0167     80.04        76          10
# 2       Te Anau      NZ -45.4167  167.7167     43.07        93         100
# 3  Puerto Ayora      EC  -0.7393  -90.3518     75.54        93           7
# 4         Aswan      EG  24.0934   32.9070     64.85        21           0
# 5     Cape Town      ZA -33.9258   18.4232     73.81        46           0
# 6     Jamestown      US  42.0970  -79.2353     19.09        66         100
# 7       Rikitea      PF -23.1203 -134.9692     77.74        73         100
# 8        Shache      CN  38.4167   77.2406     30.06        37           7
# 9          Tura      IN  25.5198   90.2201     54.25        95         100
#
#    Wind Speed Current Description
# 0        2.15     overcast clouds
# 1       13.80          light rain
# 2        3.44     overcast clouds
# 3        8.01           clear sky
# 4       19.17           clear sky
# 5        5.99           clear sky
# 6        1.99                mist
# 7       12.30     overcast clouds
# 8        7.67           clear sky
# 9        5.79     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "../Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
